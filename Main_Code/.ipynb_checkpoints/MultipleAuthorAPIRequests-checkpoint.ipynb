# %% [markdown]
# ## Use multiple Scopus Author IDs to retrieve lists of articles by author

# %%
#pip install config
# Out:
# Collecting config
#   Downloading config-0.5.0.post0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: config
# Successfully installed config-0.5.0.post0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import re
import io
from config import api_key
from collections import OrderedDict
from pandas.io.json import json_normalize

# %%
#The function "load_csv_author_ids" loads a CSV you have created that has columns called: last_name, scopus_author_id.
#This CSV may also contain other information helpful to your work. The function returns a pandas data frame called 
#"multiple_authors_df".

file_path = "radiation_oncology_without_details.csv"

def load_csv_author_ids(file_path):
    # File to Load
    multiple_authors_df = file_path

    # Read the CSV file and store into Pandas DataFrame with the column Scopus Author ID as a string
    multiple_authors_df = pd.read_csv(multiple_authors_df, encoding="utf-8", dtype ={'scopus_author_id': str})

    #Change the column names to lower case with underscore for spaces
    multiple_authors_df.columns =  multiple_authors_df.columns.str.strip().str.lower().str.replace(" ", "_").str.replace("(","").str.replace(")","")
    #radiation_oncology_df.head()
    return multiple_authors_df

multiple_authors_df = load_csv_author_ids(file_path)
load_csv_author_ids(file_path)
# Out:
#        last_name    first_name   mi  scopus_author_id       scopus_search  \
# 0       Donnelly          Eric    D       21233377200  AU-ID(21233377200)
# 1        Gentile      Michelle    S       56018970700  AU-ID(56018970700)
# 2           Gius         David    R        7003610066   AU-ID(7003610066)
# 3          Hayes          John    P       55313350000  AU-ID(55313350000)
# 4    Kalapurakal          John    A        7003993738   AU-ID(7003993738)
# 5         Kruser       Timothy    J       24448583300  AU-ID(24448583300)
# 6         Mittal        Bharat    B        7102661470   AU-ID(7102661470)
# 7         Mittal        Bharat    B       57207807061  AU-ID(57207807061)
# 8        Sachdev          Sean  NaN       56443683800  AU-ID(56443683800)
# 9   Sathiaseelan  Vythialingam  NaN        6701754514   AU-ID(6701754514)
# 10       Strauss      Jonathan    B       36143455500  AU-ID(36143455500)
# 11  Vasilopoulos    Athanasios  NaN       24336584500  AU-ID(24336584500)
# 12     Woloschak         Gayle    E        7005165328   AU-ID(7005165328)
# 13         Smith          John  NaN               453          AU-ID(453)
#
#                 unnamed:_5
# 0   AU-ID(21233377200) OR
# 1   AU-ID(56018970700) OR
# 2    AU-ID(7003610066) OR
# 3   AU-ID(55313350000) OR
# 4    AU-ID(7003993738) OR
# 5   AU-ID(24448583300) OR
# 6    AU-ID(7102661470) OR
# 7   AU-ID(57207807061) OR
# 8   AU-ID(56443683800) OR
# 9    AU-ID(6701754514) OR
# 10  AU-ID(36143455500) OR
# 11  AU-ID(24336584500) OR
# 12   AU-ID(7005165328) OR
# 13           AU-ID(453) OR

# %%
#List the column names in the dataframe
multiple_authors_df.columns
# Out:
# Index(['last_name', 'first_name', 'mi', 'scopus_author_id', 'scopus_search',
#        'unnamed:_5'],
#       dtype='object')

# %%
#Check the data type in the dataframe columns called scopus_author_id and scopus_search
multiple_authors_df.scopus_author_id.dtype
#multiple_authors_df.scopus_search.dtype
# Out:
# dtype('int64')

# %%
#The function "clean_author_id_list" takes in the multiple_authors_df and formats the "scopus_author_id" column 
#as a string, then uses the column to create a list, removes any of the "nan" values for authors that don't 
#have an ID, and finally returns a list called "cleaned_author_id_list"

def clean_author_id_list(multiple_authors_df):
    
    #Change the data type in the dataframe column called "scopus_author_id" from int64 to a string. 
    multiple_authors_df['scopus_author_id'] = multiple_authors_df['scopus_author_id'].astype(str)

    #Save the column called scopus_author_id to a list called Author_ID_List
    author_id_list = multiple_authors_df['scopus_author_id'].tolist()
    #print(author_ID_List)
    
    #Clean the Author_ID_List to remove nan
    cleaned_author_id_list = [x for x in author_id_list if str(x) != 'nan']
    #print(cleaned_author_id_list)
        
    return cleaned_author_id_list

cleaned_author_id_list = clean_author_id_list(multiple_authors_df)
clean_author_id_list(multiple_authors_df)
# Out:
# ['21233377200',
#  '56018970700',
#  '7003610066',
#  '55313350000',
#  '7003993738',
#  '24448583300',
#  '7102661470',
#  '57207807061',
#  '56443683800',
#  '6701754514',
#  '36143455500',
#  '24336584500',
#  '7005165328',
#  '453']

# %%
#The function "create_multiple_author_id_query" takes in the "cleaned_author_id_list" and adds the necessary syntax of
# "AU-ID(xxxxxxxxx)" that is required for searching Scopus Author IDs. The function returns 
#the "scopous_multiple_author_id_query".

def create_multiple_author_id_query(cleaned_author_id_list):

    #Add the necessary syntax to the cleaned_Author_ID_List
    scopus_mulitple_author_id_query = []
    for x in cleaned_author_id_list:
        authorID_string = "".join(("AU-ID(", x,")"))
        #print(authorID_string)
        scopus_mulitple_author_id_query.append(authorID_string)

    #print(scopus_mulitple_author_id_query)
    return scopus_mulitple_author_id_query

scopus_mulitple_author_id_query = create_multiple_author_id_query(cleaned_author_id_list)
create_multiple_author_id_query(cleaned_author_id_list)
# Out:
# ['AU-ID(21233377200)',
#  'AU-ID(56018970700)',
#  'AU-ID(7003610066)',
#  'AU-ID(55313350000)',
#  'AU-ID(7003993738)',
#  'AU-ID(24448583300)',
#  'AU-ID(7102661470)',
#  'AU-ID(57207807061)',
#  'AU-ID(56443683800)',
#  'AU-ID(6701754514)',
#  'AU-ID(36143455500)',
#  'AU-ID(24336584500)',
#  'AU-ID(7005165328)',
#  'AU-ID(453)']

# %%
def create_multiple_author_id_query(cleaned_author_id_list):

    #Add the necessary syntax to the cleaned_Author_ID_List
    scopus_mulitple_author_id_query = []
    for x in cleaned_author_id_list:
        authorID_string = "".join(("AU-ID(", x,")"))
        #print(authorID_string)
        scopus_mulitple_author_id_query.append(authorID_string)

    #print(scopus_mulitple_author_id_query)
    return scopus_mulitple_author_id_query

scopus_mulitple_author_id_query = create_multiple_author_id_query(cleaned_author_id_list)
create_multiple_author_id_query(cleaned_author_id_list)

#The function "get_scopus_articles" takes in the "scopus_multiple_author_id_query" and creates a necessary URL 
#for querying the Scopus API. The Scopus API key is passed in through the "headers" (see above Dependencies 
#"from config import api_key") and the config file is also referenced in the git ignore so it won't be exposed 
#on Github. The API is called and returns a response for each Scopus Author ID in the list Each response is 
#saved in a "single_author_article_dict". Each of the "single_author_article_dict" are then appended to the 
#"multiple_author_article_list". The function returns a list of dictionaries called 
#the "multiple_author_article_list". 

multiple_author_article_list = []
#multiple_author_article_dict = {}
single_author_article_dict = {}
date = "2002-2003"

# %%
#The function "get_scopus_articles" takes in the "scopus_multiple_author_id_query" and creates a necessary URL 
#for querying the Scopus API. The Scopus API key is passed in through the "headers" (see above Dependencies 
#"from config import api_key") and the config file is also referenced in the git ignore so it won't be exposed 
#on Github. The API is called and returns a response for each Scopus Author ID in the list Each response is 
#saved in a "single_author_article_dict". Each of the "single_author_article_dict" are then appended to the 
#"multiple_author_article_list". The function returns a list of dictionaries called 
#the "multiple_author_article_list". 

multiple_author_article_list = []
#multiple_author_article_dict = {}
single_author_article_dict = {}
date = "2019"
view = "Standard"
field = ["dc:title", "dc:description"]

def get_scopus_articles(scopus_mulitple_author_id_query):
    
    for authorid in scopus_mulitple_author_id_query:
        url = "http://api.elsevier.com/content/search/scopus?"           
        
        headers = {
             "X-ELS-APIKey": api_key,
             'Accept':'application/json'
        }
        parameters = {
            "query": 'nanosafety',
            "date": date, 
            "count": 10, 
            "field": field
        }
        
        #Make the API request 
        single_author_article_response = requests.get(url, headers=headers, params=parameters)
        #print(single_author_article_response.url)
        #print(single_author_article_response.status_code)
        
              
        #Append each single_author_article_dict response to multiple_author_article_list to create a list of dictionaries
        single_author_article_dict = single_author_article_response.json()
        #print(type(single_author_article_dict)) 
        #print(single_author_article_dict)
        multiple_author_article_list.append(single_author_article_dict.copy())
    
    return multiple_author_article_list
       
article_response = get_scopus_articles(scopus_mulitple_author_id_query)
article_response[0]
#References
#https://dev.elsevier.com/guides/ScopusSearchViews.htm
#https://stackoverflow.com/questions/53558837/python-loop-to-pull-api-data-for-iterating-urls
#https://stackoverflow.com/questions/36410800/python-3-parse-json-from-multiple-api-requests-into-a-list-and-output-to-a-fil
#https://www.pluralsight.com/guides/web-scraping-with-request-python
# Out:
# {'search-results': {'opensearch:totalResults': '593',
#   'opensearch:startIndex': '0',
#   'opensearch:itemsPerPage': '10',
#   'opensearch:Query': {'@role': 'request',
#    '@searchTerms': 'nanosafety',
#    '@startPage': '0'},
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=10&query=nanosafety&date=2019&field=dc%3Atitle&field=dc%3Adescription',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'first',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=10&query=nanosafety&date=2019&field=dc%3Atitle&field=dc%3Adescription',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'next',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=10&count=10&query=nanosafety&date=2019&field=dc%3Atitle&field=dc%3Adescription',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'last',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=583&count=10&query=nanosafety&date=2019&field=dc%3Atitle&field=dc%3Adescription',
#     '@type': 'application/json'}],
#   'entry': [{'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85086501672',
#     'dc:title': 'Microfluidic Synthesis of Functional Nanoparticles'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072221469',
#     'dc:title': 'Simultaneous delivery of DNA vaccine and hydrophobic adjuvant using reducible polyethylenimine-functionalized graphene oxide for activation of dendritic cells'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85077126047',
#     'dc:title': 'Size-dependent tissue-specific biological effects of core-shell structured Fe<inf>3</inf>O<inf>4</inf>@SiO<inf>2</inf>-NH<inf>2</inf> nanoparticles'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85076629230',
#     'dc:title': 'Nucleic acid nanoparticles at a crossroads of vaccines and immunotherapies'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072724446',
#     'dc:title': 'Selenium modulated gut flora and promoted decomposition of methylmercury in methylmercury-poisoned rats'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85075653386',
#     'dc:title': 'Plasmon-Enhanced Oxidase-Like Activity and Cellular Effect of Pd-Coated Gold Nanorods'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85075078074',
#     'dc:title': 'Cold-Responsive Nanoparticle Enables Intracellular Delivery and Rapid Release of Trehalose for Organic-Solvent-Free Cryopreservation'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85073832238',
#     'dc:title': 'Turning Challenges into Opportunities for Promoting Systems Thinking through Chemistry Education'},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85074568300',
#     'dc:title': "Organoplatinum-Substituted Polyoxometalate Inhibits β-amyloid Aggregation for Alzheimer's Therapy"},
#    {'@_fa': 'true',
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85076205912',
#     'dc:title': 'Predominance of secondary organic aerosol to particle-bound reactive oxygen species activity in fine ambient aerosol'}]}}

# %%
url = "http://api.elsevier.com/content/search/scopus?" + "?format=json"
headers = {"X-ELS-APIKey": api_key, 'Accept':'application/json'}
parameters = {"query": 'nanosafety', "view": "Complete", "date": date}
article_response_2 = requests.get(url, headers=headers, params=parameters)
article_response_2.json()
# Out:
# {'search-results': {'opensearch:totalResults': '593',
#   'opensearch:startIndex': '0',
#   'opensearch:itemsPerPage': '25',
#   'opensearch:Query': {'@role': 'request',
#    '@searchTerms': 'nanosafety',
#    '@startPage': '0'},
#   'link': [{'@_fa': 'true',
#     '@ref': 'self',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=nanosafety&view=Complete&date=2019',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'first',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=0&count=25&query=nanosafety&view=Complete&date=2019',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'next',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=25&count=25&query=nanosafety&view=Complete&date=2019',
#     '@type': 'application/json'},
#    {'@_fa': 'true',
#     '@ref': 'last',
#     '@href': 'https://api.elsevier.com/content/search/scopus?start=568&count=25&query=nanosafety&view=Complete&date=2019',
#     '@type': 'application/json'}],
#   'entry': [{'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85086501672'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85086501672?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85086501672&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85086501672&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85086501672',
#     'dc:identifier': 'SCOPUS_ID:85086501672',
#     'eid': '2-s2.0-85086501672',
#     'dc:title': 'Microfluidic Synthesis of Functional Nanoparticles',
#     'dc:creator': 'Han Z.',
#     'prism:publicationName': 'Nanotechnology for Microfluidics',
#     'prism:isbn': [{'@_fa': 'true', '$': '9783527818334'},
#      {'@_fa': 'true', '$': '9783527345335'}],
#     'prism:pageRange': '319-345',
#     'prism:coverDate': '2019-12-31',
#     'prism:coverDisplayDate': '31 December 2019',
#     'prism:doi': '10.1002/9783527818341.ch10',
#     'dc:description': 'This chapter focuses on microfluidic-based synthesis of functional nanoparti-cles as well as their biological and medical applications. It provides an introduction to microfluidic synthesis strategy and the fabrication of microfluidic dives. The chapter explores synthesis and applications of microfluidic assembly of functional nanoparticles on disease therapy and diagnosis. It demonstrates the potential applications and remaining challenges of microfluidic synthesized nanoparticles. For many medical and scientific purposes, nanoparticles can be designed to have some specific characteristics including size, compositions, structural properties, and surface modifications. The synthesis of nanoparticles through microfluidic chips is usually a one-step method: after the reaction reagents are injected into the inlets, functional nanoparticles can emerge. For nanoparticles, size is one of the most important parameters that their biological and physicochemical properties highly relied on. The same nanomaterials with different sizes could have distinguished performance in biomedical experiments.',
#     'citedby-count': '4',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60105683',
#       'afid': '60105683',
#       'affilname': 'Southern University of Science and Technology',
#       'affiliation-city': 'Shenzhen',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073473',
#       'afid': '60073473',
#       'affilname': 'National Center for Nanoscience and Technology Beijing',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027363',
#       'afid': '60027363',
#       'affilname': 'University of Chinese Academy of Sciences',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Book',
#     'subtype': 'ch',
#     'subtypeDescription': 'Chapter',
#     'author-count': {'@limit': '100', '@total': '2', '$': '2'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57215901093',
#       'authid': '57215901093',
#       'authname': 'Han Z.',
#       'surname': 'Han',
#       'given-name': 'Ziwei',
#       'initials': 'Z.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60105683'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/15754137400',
#       'authid': '15754137400',
#       'authname': 'Jiang X.',
#       'surname': 'Jiang',
#       'given-name': 'Xingyu',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60105683'},
#        {'@_fa': 'true', '$': '60027363'}]}],
#     'authkeywords': 'Biomedical experiments | Functional nanoparticles | Microfluidic synthesis | Physicochemical properties | Structural properties | Surface modification',
#     'source-id': '21101037311',
#     'fund-no': 'undefined',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072221469'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072221469?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072221469&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072221469&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S1226086X1930440X'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072221469',
#     'dc:identifier': 'SCOPUS_ID:85072221469',
#     'eid': '2-s2.0-85072221469',
#     'dc:title': 'Simultaneous delivery of DNA vaccine and hydrophobic adjuvant using reducible polyethylenimine-functionalized graphene oxide for activation of dendritic cells',
#     'dc:creator': 'Yin Y.',
#     'prism:publicationName': 'Journal of Industrial and Engineering Chemistry',
#     'prism:issn': '1226086X',
#     'prism:eIssn': '22345957',
#     'prism:volume': '80',
#     'prism:pageRange': '870-876',
#     'prism:coverDate': '2019-12-25',
#     'prism:coverDisplayDate': '25 December 2019',
#     'prism:doi': '10.1016/j.jiec.2019.08.038',
#     'pii': 'S1226086X1930440X',
#     'dc:description': 'The activation and maturation of dendritic cells are critical in immunotherapy, and the potency of DCs is associated with high levels of antigen presentation on major histocompatibility complex (MHC) class I and II and the expression of costimulatory signals. Graphene oxide (GO) and its derivatives have many excellent physicochemical properties, including large and hydrophobic surface available for interacting with hydrophobic or aromatic drugs via π–π stacking forces, flexibility of the chemical modification on the surfaces, and capacity of DC activation. In this study, we designed a simple strategy to achieve the co-delivery of a DNA vaccine and hydrophobic immune adjuvant (R848) and to enhance the adjuvanticity of R848 via the synergistic effect of GO and R848. Thiolated low-molecular-weight polyethylenimine (TPEI1.8) was crosslinked with 4-aminothiophenol-modified GO (TGO) via the formation of disulfide bonds. Thus, TGO with its assembled TPEI1.8 could not only load R848 but also electrostatically interact with the DNA vaccine. Owing to the reducibility of the disulfide bond in the cellular environment, the DNA vaccine could be readily released. This system can significantly enhance the DNA transfection, the expression of the costimulatory signal, and the level of antigen presentation to MHC class I DCs for their activation and maturation.',
#     'citedby-count': '3',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073473',
#       'afid': '60073473',
#       'affilname': 'National Center for Nanoscience and Technology Beijing',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60007511',
#       'afid': '60007511',
#       'affilname': 'Sungkyunkwan University',
#       'affiliation-city': 'Seoul',
#       'affiliation-country': 'South Korea'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '8', '$': '8'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57197786051',
#       'authid': '57197786051',
#       'authname': 'Yin Y.',
#       'surname': 'Yin',
#       'given-name': 'Yue',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60073473'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57195420570',
#       'authid': '57195420570',
#       'authname': 'Nguyen T.L.',
#       'surname': 'Nguyen',
#       'given-name': 'Thanh Loc',
#       'initials': 'T.L.',
#       'afid': [{'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56949231400',
#       'authid': '56949231400',
#       'authname': 'Wang B.',
#       'surname': 'Wang',
#       'given-name': 'Bo',
#       'initials': 'B.',
#       'afid': [{'@_fa': 'true', '$': '60007511'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57190377590',
#       'authid': '57190377590',
#       'authname': 'Duong H.T.T.',
#       'surname': 'Duong',
#       'given-name': 'Huu Thuy Trang',
#       'initials': 'H.T.T.',
#       'afid': [{'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/35074295300',
#       'authid': '35074295300',
#       'authname': 'Lee D.S.',
#       'surname': 'Lee',
#       'given-name': 'Doo Sung',
#       'initials': 'D.S.',
#       'afid': [{'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/36063077600',
#       'authid': '36063077600',
#       'authname': 'Kim J.H.',
#       'surname': 'Kim',
#       'given-name': 'Ji Heung',
#       'initials': 'J.H.',
#       'afid': [{'@_fa': 'true', '$': '60007511'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/9437375400',
#       'authid': '9437375400',
#       'orcid': '0000-0002-4687-6732',
#       'authname': 'Kim J.',
#       'surname': 'Kim',
#       'given-name': 'Jaeyun',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'}]},
#      {'@_fa': 'true',
#       '@seq': '8',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57202824015',
#       'authid': '57202824015',
#       'orcid': '0000-0002-4836-3551',
#       'authname': 'Jeong J.H.',
#       'surname': 'Jeong',
#       'given-name': 'Ji Hoon',
#       'initials': 'J.H.',
#       'afid': [{'@_fa': 'true', '$': '60007511'},
#        {'@_fa': 'true', '$': '60007511'}]}],
#     'authkeywords': 'Dendritic cells | DNA vaccine | Gene delivery | Graphene oxide | Vaccine adjuvant',
#     'source-id': '144861',
#     'fund-acr': 'MOTIE',
#     'fund-no': '10077704',
#     'fund-sponsor': 'Ministry of Trade, Industry and Energy',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85077126047'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85077126047?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85077126047&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85077126047&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85077126047',
#     'dc:identifier': 'SCOPUS_ID:85077126047',
#     'eid': '2-s2.0-85077126047',
#     'dc:title': 'Size-dependent tissue-specific biological effects of core-shell structured Fe<inf>3</inf>O<inf>4</inf>@SiO<inf>2</inf>-NH<inf>2</inf> nanoparticles',
#     'dc:creator': 'Li J.',
#     'prism:publicationName': 'Journal of Nanobiotechnology',
#     'prism:eIssn': '14773155',
#     'prism:volume': '17',
#     'prism:issueIdentifier': '1',
#     'prism:pageRange': None,
#     'prism:coverDate': '2019-12-23',
#     'prism:coverDisplayDate': '23 December 2019',
#     'prism:doi': '10.1186/s12951-019-0561-4',
#     'dc:description': 'Background: Understanding the in vivo size-dependent pharmacokinetics and toxicity of nanoparticles is crucial to determine their successful development. Systematic studies on the size-dependent biological effects of nanoparticles not only help to unravel unknown toxicological mechanism but also contribute to the possible biological applications of nanomaterial. Methods: In this study, the biodistribution and the size-dependent biological effects of Fe3O4@SiO2-NH2 nanoparticles (Fe@Si-NPs) in three diameters (10, 20 and 40 nm) were investigated by ICP-AES, serum biochemistry analysis and NMR-based metabolomic analysis after intravenous administration in a rat model. Results: Our findings indicated that biodistribution and biological activities of Fe@Si-NPs demonstrated the obvious size-dependent and tissue-specific effects. Spleen and liver are the target tissues of Fe@Si-NPs, and 20 nm of Fe@Si-NPs showed a possible longer blood circulation time. Quantitative biochemical analysis showed that the alterations of lactate dehydrogenase (LDH) and uric acid (UA) were correlated to some extent with the sizes of Fe@Si-NPs. The untargeted metabolomic analyses of tissue metabolomes (kidney, liver, lung, and spleen) indicated that different sizes of Fe@Si-NPs were involved in the different biochemical mechanisms. LDH, formate, uric acid, and GSH related metabolites were suggested as sensitive indicators for the size-dependent toxic effects of Fe@Si-NPs. The findings from serum biochemical analysis and metabolomic analysis corroborate each other. Thus we proposed a toxicity hypothesis that size-dependent NAD depletion may occur in vivo in response to nanoparticle exposure. To our knowledge, this is the first report that links size-dependent biological effects of nanoparticles with in vivo NAD depletion in rats. Conclusion: The integrated metabolomic approach is an effective tool to understand physiological responses to the size-specific properties of nanoparticles. Our results can provide a direction for the future biological applications of Fe@Si-NPs.',
#     'citedby-count': '6',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60021182',
#       'afid': '60021182',
#       'affilname': 'Sun Yat-Sen University',
#       'affiliation-city': 'Guangzhou',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019706',
#       'afid': '60019706',
#       'affilname': 'Wuhan Institute of Physics and Mathematics Chinese Academy of Sciences',
#       'affiliation-city': 'Wuhan',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60018205',
#       'afid': '60018205',
#       'affilname': 'Xiamen University',
#       'affiliation-city': 'Xiamen',
#       'affiliation-country': 'China'}],
#     'pubmed-id': '31870377',
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '5', '$': '5'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55899984600',
#       'authid': '55899984600',
#       'authname': 'Li J.',
#       'surname': 'Li',
#       'given-name': 'Jinquan',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60021182'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57201723010',
#       'authid': '57201723010',
#       'authname': 'Yuan Z.',
#       'surname': 'Yuan',
#       'given-name': 'Zhongxue',
#       'initials': 'Z.',
#       'afid': [{'@_fa': 'true', '$': '60018205'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/36620403100',
#       'authid': '36620403100',
#       'authname': 'Liu H.',
#       'surname': 'Liu',
#       'given-name': 'Huili',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '60019706'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/7403884623',
#       'authid': '7403884623',
#       'orcid': '0000-0001-8899-2750',
#       'authname': 'Feng J.',
#       'surname': 'Feng',
#       'given-name': 'Jianghua',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60018205'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57213095875',
#       'authid': '57213095875',
#       'authname': 'Chen Z.',
#       'surname': 'Chen',
#       'given-name': 'Zhong',
#       'initials': 'Z.',
#       'afid': [{'@_fa': 'true', '$': '60018205'}]}],
#     'authkeywords': 'Core-shell structure nanoparticle | Size effect | Toxicity assessment | Untargeted metabolomics',
#     'article-number': '124',
#     'source-id': '16088',
#     'fund-acr': 'NSFC',
#     'fund-no': '31671920',
#     'fund-sponsor': 'National Natural Science Foundation of China',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85076629230'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85076629230?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85076629230&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85076629230&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85076629230',
#     'dc:identifier': 'SCOPUS_ID:85076629230',
#     'eid': '2-s2.0-85076629230',
#     'dc:title': 'Nucleic acid nanoparticles at a crossroads of vaccines and immunotherapies',
#     'dc:creator': 'Dobrovolskaia M.A.',
#     'prism:publicationName': 'Molecules',
#     'prism:eIssn': '14203049',
#     'prism:volume': '24',
#     'prism:issueIdentifier': '24',
#     'prism:pageRange': None,
#     'prism:coverDate': '2019-12-17',
#     'prism:coverDisplayDate': '17 December 2019',
#     'prism:doi': '10.3390/molecules24244620',
#     'dc:description': 'Vaccines and immunotherapies involve a variety of technologies and act through different mechanisms to achieve a common goal, which is to optimize the immune response against an antigen. The antigen could be a molecule expressed on a pathogen (e.g., a disease-causing bacterium, a virus or another microorganism), abnormal or damaged host cells (e.g., cancer cells), environmental agent (e.g., nicotine from a tobacco smoke), or an allergen (e.g., pollen or food protein). Immunogenic vaccines and therapies optimize the immune response to improve the eradication of the pathogen or damaged cells. In contrast, tolerogenic vaccines and therapies retrain or blunt the immune response to antigens, which are recognized by the immune system as harmful to the host. To optimize the immune response to either improve the immunogenicity or induce tolerance, researchers employ different routes of administration, antigen-delivery systems, and adjuvants. Nanocarriers and adjuvants are of particular interest to the fields of vaccines and immunotherapy as they allow for targeted delivery of the antigens and direct the immune response against these antigens in desirable direction (i.e., to either enhance immunogenicity or induce tolerance). Recently, nanoparticles gained particular attention as antigen carriers and adjuvants. This review focuses on a particular subclass of nanoparticles, which are made of nucleic acids, so-called nucleic acid nanoparticles or NANPs. Immunological properties of these novel materials and considerations for their clinical translation are discussed.',
#     'citedby-count': '11',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027053',
#       'afid': '60027053',
#       'affilname': 'National Cancer Institute at Frederick',
#       'affiliation-city': 'Frederick',
#       'affiliation-country': 'United States'}],
#     'pubmed-id': '31861154',
#     'prism:aggregationType': 'Journal',
#     'subtype': 're',
#     'subtypeDescription': 'Review',
#     'author-count': {'@limit': '100', '@total': '1', '$': '1'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/8715205600',
#       'authid': '8715205600',
#       'authname': 'Dobrovolskaia M.A.',
#       'surname': 'Dobrovolskaia',
#       'given-name': 'Marina A.',
#       'initials': 'M.A.',
#       'afid': [{'@_fa': 'true', '$': '60027053'}]}],
#     'authkeywords': 'Adjuvants | Antibody | Antigen-presenting cells | Immunotherapy | Immunotoxicity | In vitro | In vivo | Nanoparticles | Nanotechnology | Preclinical | Safety | Translation | Vaccines',
#     'article-number': '4620',
#     'source-id': '26370',
#     'fund-acr': 'NIH',
#     'fund-no': '75N91019D00024',
#     'fund-sponsor': 'National Institutes of Health',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072724446'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85072724446?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85072724446&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85072724446&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'full-text',
#       '@href': 'https://api.elsevier.com/content/article/eid/1-s2.0-S0147651319310516'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85072724446',
#     'dc:identifier': 'SCOPUS_ID:85072724446',
#     'eid': '2-s2.0-85072724446',
#     'dc:title': 'Selenium modulated gut flora and promoted decomposition of methylmercury in methylmercury-poisoned rats',
#     'dc:creator': 'Liu Y.',
#     'prism:publicationName': 'Ecotoxicology and Environmental Safety',
#     'prism:issn': '01476513',
#     'prism:eIssn': '10902414',
#     'prism:volume': '185',
#     'prism:pageRange': None,
#     'prism:coverDate': '2019-12-15',
#     'prism:coverDisplayDate': '15 December 2019',
#     'prism:doi': '10.1016/j.ecoenv.2019.109720',
#     'pii': 'S0147651319310516',
#     'dc:description': 'Introduction: Selenium plays important roles in antagonizing the toxicity of methylmercury. The underlying mechanism for the antagonism between Se and MeHg is still not fully understood. Objective: The role of gut flora against the toxicity of environmental contaminants is receiving more and more attention. The objective of this study was to investigate the role of Se against MeHg-poisoning in the modulation of gut flora and the decomposition of MeHg. Methods: MeHg-poisoned rats were treated with sodium selenite every other day for 90 days. Fecal samples were collected on Day 8, 30, 60 and 90. Gut flora in feces was determined using 16S rRNA gene profiling, and the concentrations of Se and total mercury (THg) were measured by ICP-MS, and the concentration of MeHg was measured by CVAFS. Results: Gut flora at both the ranks of phylum and genus in the MeHg-poisoned rats after Se treatment was modulated towards that in the control group, suggesting the restoration of the profile of gut flora. Increased THg was found in fecal samples after Se treatment on day 30. The percentage of MeHg (of total mercury) in the MeHg-poisoned group was in the range of 81–105% while it was 65–84% in the Se treatment group on different days, suggesting the increased decomposition of MeHg in MeHg-poisoned rats after Se treatment. Conclusions: This study suggests that MeHg poisoning damaged the abundance of gut flora and decreased their capacity for the decomposition of MeHg. After Se treatment, the abundance of gut flora was partially restored and the decomposition and excretion of MeHg was enhanced. These findings suggest that the modulation of gut flora may be one way to promote the health status in MeHg-poisoned rats and possibly in human beings.',
#     'citedby-count': '17',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60104165',
#       'afid': '60104165',
#       'affilname': 'Inner Mongolia University of Science and Technology',
#       'affiliation-city': 'Baotou',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60103801',
#       'afid': '60103801',
#       'affilname': 'University of Jinan',
#       'affiliation-city': 'Jinan',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073473',
#       'afid': '60073473',
#       'affilname': 'National Center for Nanoscience and Technology Beijing',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60031041',
#       'afid': '60031041',
#       'affilname': 'Northwest A&amp;F University',
#       'affiliation-city': 'Yangling',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027631',
#       'afid': '60027631',
#       'affilname': 'Institute of High Energy Physics Chinese Academy of Science',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/122252618',
#       'afid': '122252618',
#       'affilname': 'PLA 960 Hospital',
#       'affiliation-city': 'Jinan',
#       'affiliation-country': 'China'}],
#     'pubmed-id': '31585392',
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '11', '$': '11'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56178781300',
#       'authid': '56178781300',
#       'authname': 'Liu Y.',
#       'surname': 'Liu',
#       'given-name': 'Yang',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60104165'},
#        {'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211123825',
#       'authid': '57211123825',
#       'authname': 'Ji J.',
#       'surname': 'Ji',
#       'given-name': 'Jun',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60104165'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57202664382',
#       'authid': '57202664382',
#       'authname': 'Zhang W.',
#       'surname': 'Zhang',
#       'given-name': 'Wei',
#       'initials': 'W.',
#       'afid': [{'@_fa': 'true', '$': '60027631'},
#        {'@_fa': 'true', '$': '60103801'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57217394446',
#       'authid': '57217394446',
#       'authname': 'Suo Y.',
#       'surname': 'Suo',
#       'given-name': 'Yao',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60031041'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/36627796400',
#       'authid': '36627796400',
#       'authname': 'Zhao J.',
#       'surname': 'Zhao',
#       'given-name': 'Jiating',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57201820859',
#       'authid': '57201820859',
#       'authname': 'Lin X.',
#       'surname': 'Lin',
#       'given-name': 'Xiaoying',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57190275433',
#       'authid': '57190275433',
#       'authname': 'Cui L.',
#       'surname': 'Cui',
#       'given-name': 'Liwei',
#       'initials': 'L.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '8',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55561892600',
#       'authid': '55561892600',
#       'authname': 'Li B.',
#       'surname': 'Li',
#       'given-name': 'Bai',
#       'initials': 'B.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '9',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/14035344900',
#       'authid': '14035344900',
#       'authname': 'Hu H.',
#       'surname': 'Hu',
#       'given-name': 'Huaiqiang',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '122252618'}]},
#      {'@_fa': 'true',
#       '@seq': '10',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/7501954692',
#       'authid': '7501954692',
#       'authname': 'Chen C.',
#       'surname': 'Chen',
#       'given-name': 'Chunying',
#       'initials': 'C.',
#       'afid': [{'@_fa': 'true', '$': '60073473'}]},
#      {'@_fa': 'true',
#       '@seq': '11',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55876450300',
#       'authid': '55876450300',
#       'authname': 'Li Y.F.',
#       'surname': 'Li',
#       'given-name': 'Yu Feng',
#       'initials': 'Y.F.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]}],
#     'authkeywords': '16S rRNA | Feces | Gut flora | Methylmercury | Rats | Selenite',
#     'article-number': '109720',
#     'source-id': '25076',
#     'fund-acr': 'NSFC',
#     'fund-no': 'BSJJ201813',
#     'fund-sponsor': 'National Natural Science Foundation of China',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85075653386'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85075653386?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075653386&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85075653386&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85075653386',
#     'dc:identifier': 'SCOPUS_ID:85075653386',
#     'eid': '2-s2.0-85075653386',
#     'dc:title': 'Plasmon-Enhanced Oxidase-Like Activity and Cellular Effect of Pd-Coated Gold Nanorods',
#     'dc:creator': 'Fan H.',
#     'prism:publicationName': 'ACS Applied Materials and Interfaces',
#     'prism:issn': '19448244',
#     'prism:eIssn': '19448252',
#     'prism:volume': '11',
#     'prism:issueIdentifier': '49',
#     'prism:pageRange': '45416-45426',
#     'prism:coverDate': '2019-12-11',
#     'prism:coverDisplayDate': '11 December 2019',
#     'prism:doi': '10.1021/acsami.9b16286',
#     'dc:description': 'Local surface plasmon resonance (LSPR)-enhanced catalysis has attracted much attention recently. Palladium nanoparticles have been reported to have various nanozyme activities and exhibit promising potentials for biomedical applications. However, as Pd is a poor plasmonic metal, little attention has been paid to its LSPR-regulated nanozyme activity. Herein, by using Au nanorods (AuNRs) as a strong plasmonic core, we coated a thin layer Pd to form a rod-shaped core-shell structure. The obtained Au@PdNRs showed tunable LSPR bands in the near-infrared (NIR) spectral range inheriting from the Au core and yet an exposed Pd surface for catalysis. The oxidase-like activity was investigated in the dark and upon SPR excitation. The plasmon-enhanced activity was observed and was mainly ascribed to the local photothermal effect. Finally, to enhance biocompatibility, mesoporous silica-coated nanorods were used to detect the oxidase-like activity in cells. After being endocytosed by cells, upon plasmon excitation, the oxidase activity of Au@PdNRs could be manifested and lead to higher cytotoxicity and depolarization of mitochondrial membrane potential. Our studies highlight the feasibility of regulating the nanozyme activity of plasmonic nanostructures using their unique NIR plasmonic features with spatiotemporal control.',
#     'citedby-count': '8',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60104152',
#       'afid': '60104152',
#       'affilname': 'Zaozhuang University',
#       'affiliation-city': 'Zaozhuang',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073473',
#       'afid': '60073473',
#       'affilname': 'National Center for Nanoscience and Technology Beijing',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027363',
#       'afid': '60027363',
#       'affilname': 'University of Chinese Academy of Sciences',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'}],
#     'pubmed-id': '31713410',
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '9', '$': '9'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57195354364',
#       'authid': '57195354364',
#       'orcid': '0000-0001-7646-888X',
#       'authname': 'Fan H.',
#       'surname': 'Fan',
#       'given-name': 'Huizhen',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/35783199400',
#       'authid': '35783199400',
#       'orcid': '0000-0001-9396-2345',
#       'authname': 'Li Y.',
#       'surname': 'Li',
#       'given-name': 'Yiye',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57015811700',
#       'authid': '57015811700',
#       'authname': 'Liu J.',
#       'surname': 'Liu',
#       'given-name': 'Jianbo',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60104152'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57213963097',
#       'authid': '57213963097',
#       'authname': 'Cai R.',
#       'surname': 'Cai',
#       'given-name': 'Rui',
#       'initials': 'R.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57212004230',
#       'authid': '57212004230',
#       'authname': 'Gao X.',
#       'surname': 'Gao',
#       'given-name': 'Xinshuang',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56979559000',
#       'authid': '56979559000',
#       'authname': 'Zhang H.',
#       'surname': 'Zhang',
#       'given-name': 'Hui',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/36466473900',
#       'authid': '36466473900',
#       'authname': 'Ji Y.',
#       'surname': 'Ji',
#       'given-name': 'Yinglu',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '8',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/8606966100',
#       'authid': '8606966100',
#       'orcid': '0000-0001-5040-9793',
#       'authname': 'Nie G.',
#       'surname': 'Nie',
#       'given-name': 'Guangjun',
#       'initials': 'G.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '9',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55641905400',
#       'authid': '55641905400',
#       'authname': 'Wu X.',
#       'surname': 'Wu',
#       'given-name': 'Xiaochun',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]}],
#     'authkeywords': 'Au@PdNRs | core-shell nanostructure | nanozyme | plasmonic catalysis | reactive oxygen species',
#     'source-id': '19700171101',
#     'fund-acr': 'NSFC',
#     'fund-no': '31571021',
#     'fund-sponsor': 'National Natural Science Foundation of China',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85075078074'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85075078074?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85075078074&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85075078074&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85075078074',
#     'dc:identifier': 'SCOPUS_ID:85075078074',
#     'eid': '2-s2.0-85075078074',
#     'dc:title': 'Cold-Responsive Nanoparticle Enables Intracellular Delivery and Rapid Release of Trehalose for Organic-Solvent-Free Cryopreservation',
#     'dc:creator': 'Zhang Y.',
#     'prism:publicationName': 'Nano Letters',
#     'prism:issn': '15306984',
#     'prism:eIssn': '15306992',
#     'prism:volume': '19',
#     'prism:issueIdentifier': '12',
#     'prism:pageRange': '9051-9061',
#     'prism:coverDate': '2019-12-11',
#     'prism:coverDisplayDate': '11 December 2019',
#     'prism:doi': '10.1021/acs.nanolett.9b04109',
#     'dc:description': 'Conventional cryopreservation of mammalian cells requires the use of toxic organic solvents (e.g., dimethyl sulfoxide) as cryoprotectants. Consequently, the cryopreserved cells must undergo a tedious washing procedure to remove the organic solvents for their further applications in cell-based medicine, and many of the precious cells may be lost or killed during the procedure. Trehalose has been explored as a nontoxic alternative to traditional cryoprotectants. However, mammalian cells do not synthesize trehalose or express trehalose transporters in their membranes, and the lack of an approach for the efficient intracellular delivery of trehalose has been a major hurdle for its use in cell cryopreservation. In this study, a cold-responsive polymer (poly(N-isopropylacrylamide-co-butyl acrylate)) is utilized to synthesize nanoparticles for the encapsulation and intracellular delivery of trehalose. The trehalose-laden nanoparticles can be efficiently taken up by mammalian cells. The nanoparticles quickly and irreversibly disassemble upon cold treatment, enabling the controlled and rapid release of trehalose from the nanoparticles inside cells. The latter is confirmed by an evident increase in cell volume upon cold treatment. This rapid cold-triggered intracellular release of trehalose is crucial to developing a fast protocol to cryopreserve cells using trehalose. Cells with intracellular trehalose delivered using the nanoparticles show comparable postcryopreservation viability compared to that of cells treated with DMSO, eliminating the need for the tedious and cell-damaging washing procedure required for using the DMSO-cryopreserved cells in vivo. This cold-responsive nanoparticle may greatly facilitate the use of trehalose as a nontoxic cryoprotectant for banking cells and tissues to meet their high demand by modern cell-based medicine.',
#     'citedby-count': '13',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60078684',
#       'afid': '60078684',
#       'affilname': 'A. James Clark School of Engineering',
#       'affiliation-city': 'College Park',
#       'affiliation-country': 'United States'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073473',
#       'afid': '60073473',
#       'affilname': 'National Center for Nanoscience and Technology Beijing',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027363',
#       'afid': '60027363',
#       'affilname': 'University of Chinese Academy of Sciences',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60019118',
#       'afid': '60019118',
#       'affilname': 'University of Science and Technology of China',
#       'affiliation-city': 'Hefei',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60014653',
#       'afid': '60014653',
#       'affilname': 'University of Maryland, Baltimore (UMB)',
#       'affiliation-city': 'Baltimore',
#       'affiliation-country': 'United States'}],
#     'pubmed-id': '31680526',
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '7', '$': '7'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56184950000',
#       'authid': '56184950000',
#       'authname': 'Zhang Y.',
#       'surname': 'Zhang',
#       'given-name': 'Yuntian',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60078684'},
#        {'@_fa': 'true', '$': '60019118'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56449975100',
#       'authid': '56449975100',
#       'authname': 'Wang H.',
#       'surname': 'Wang',
#       'given-name': 'Hai',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '60078684'},
#        {'@_fa': 'true', '$': '60073473'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57203576155',
#       'authid': '57203576155',
#       'authname': 'Stewart S.',
#       'surname': 'Stewart',
#       'given-name': 'Samantha',
#       'initials': 'S.',
#       'afid': [{'@_fa': 'true', '$': '60078684'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57214351849',
#       'authid': '57214351849',
#       'authname': 'Jiang B.',
#       'surname': 'Jiang',
#       'given-name': 'Bin',
#       'initials': 'B.',
#       'afid': [{'@_fa': 'true', '$': '60078684'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211802347',
#       'authid': '57211802347',
#       'authname': 'Ou W.',
#       'surname': 'Ou',
#       'given-name': 'Wenquan',
#       'initials': 'W.',
#       'afid': [{'@_fa': 'true', '$': '60078684'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56518686600',
#       'authid': '56518686600',
#       'orcid': '0000-0002-0201-1825',
#       'authname': 'Zhao G.',
#       'surname': 'Zhao',
#       'given-name': 'Gang',
#       'initials': 'G.',
#       'afid': [{'@_fa': 'true', '$': '60078684'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57051763800',
#       'authid': '57051763800',
#       'orcid': '0000-0003-0125-6086',
#       'authname': 'He X.',
#       'surname': 'He',
#       'given-name': 'Xiaoming',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60078684'},
#        {'@_fa': 'true', '$': '60078684'},
#        {'@_fa': 'true', '$': '60014653'}]}],
#     'authkeywords': 'butyl acrylate | Cold-responsive | cryopreservation | pNIPAM | stem cell | trehalose',
#     'source-id': '17853',
#     'fund-no': 'CBET-1831019',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85073832238'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85073832238?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
# ...
#       'given-name': 'Guangjun',
#       'initials': 'G.',
#       'afid': [{'@_fa': 'true', '$': '60027363'},
#        {'@_fa': 'true', '$': '60073473'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56979584900',
#       'authid': '56979584900',
#       'orcid': '0000-0002-0565-0411',
#       'authname': 'Zhang H.',
#       'surname': 'Zhang',
#       'given-name': 'Hui',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '60000338'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/12767677700',
#       'authid': '12767677700',
#       'orcid': '0000-0003-3717-2423',
#       'authname': 'Gu Z.',
#       'surname': 'Gu',
#       'given-name': 'Zhanjun',
#       'initials': 'Z.',
#       'afid': [{'@_fa': 'true', '$': '60027631'},
#        {'@_fa': 'true', '$': '60027363'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/7407400077',
#       'authid': '7407400077',
#       'authname': 'Zhao Y.',
#       'surname': 'Zhao',
#       'given-name': 'Yuliang',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60027363'},
#        {'@_fa': 'true', '$': '60073473'}]}],
#     'authkeywords': 'carbon monoxide | nanomaterials | therapeutic applications',
#     'article-number': '1904382',
#     'source-id': '3200147828',
#     'fund-acr': 'NSFC',
#     'fund-no': 'YT1601',
#     'fund-sponsor': 'National Natural Science Foundation of China',
#     'openaccess': '0',
#     'openaccessFlag': False},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85074588316'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85074588316?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074588316&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85074588316&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85074588316',
#     'dc:identifier': 'SCOPUS_ID:85074588316',
#     'eid': '2-s2.0-85074588316',
#     'dc:title': 'Self-Supply of O<inf>2</inf> and H<inf>2</inf>O<inf>2</inf> by a Nanocatalytic Medicine to Enhance Combined Chemo/Chemodynamic Therapy',
#     'dc:creator': 'Gao S.',
#     'prism:publicationName': 'Advanced Science',
#     'prism:eIssn': '21983844',
#     'prism:volume': '6',
#     'prism:issueIdentifier': '24',
#     'prism:pageRange': None,
#     'prism:coverDate': '2019-12-01',
#     'prism:coverDisplayDate': '1 December 2019',
#     'prism:doi': '10.1002/advs.201902137',
#     'dc:description': 'Combined chemo/chemodynamic therapy is a promising strategy to achieve an improved anticancer effect. However, the hypoxic microenvironment and limited amount of H2O2 in most solid tumors severely restrict the efficacy of this treatment. Herein, the construction of a nanocatalytic medicine, CaO2@DOX@ZIF-67, via a bottom-up approach is described. CaO2@DOX@ZIF-67 simultaneously supplies O2 and H2O2 to achieve improved chemo/chemodynamic therapy. In the weakly acidic environment within tumors, CaO2@DOX@ZIF-67 is broken down to rapidly release the Fenton-like catalyst Co2+ and the chemotherapy drug doxorubicin (DOX). The unprotected CaO2 reacts with H2O to generate both O2 and H2O2. The generated O2 relieves the hypoxia in the tumor and further improve the efficacy of DOX. Meanwhile, the generated H2O2 reacts with Co2+ ions to produce highly toxic •OH through a Fenton-like reaction, resulting in improved chemodynamic therapy.',
#     'citedby-count': '66',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60073473',
#       'afid': '60073473',
#       'affilname': 'National Center for Nanoscience and Technology Beijing',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60015407',
#       'afid': '60015407',
#       'affilname': 'Hebei Agricultural University',
#       'affiliation-city': 'Baoding',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60012293',
#       'afid': '60012293',
#       'affilname': 'Hebei University',
#       'affiliation-city': 'Baoding',
#       'affiliation-country': 'China'}],
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '10', '$': '10'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/22953744600',
#       'authid': '22953744600',
#       'authname': 'Gao S.',
#       'surname': 'Gao',
#       'given-name': 'Shutao',
#       'initials': 'S.',
#       'afid': [{'@_fa': 'true', '$': '60012293'},
#        {'@_fa': 'true', '$': '60015407'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57201346604',
#       'authid': '57201346604',
#       'authname': 'Jin Y.',
#       'surname': 'Jin',
#       'given-name': 'Yan',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/35573319400',
#       'authid': '35573319400',
#       'authname': 'Ge K.',
#       'surname': 'Ge',
#       'given-name': 'Kun',
#       'initials': 'K.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57203156154',
#       'authid': '57203156154',
#       'authname': 'Li Z.',
#       'surname': 'Li',
#       'given-name': 'Zhenhua',
#       'initials': 'Z.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56038033100',
#       'authid': '56038033100',
#       'authname': 'Liu H.',
#       'surname': 'Liu',
#       'given-name': 'Huifang',
#       'initials': 'H.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211604116',
#       'authid': '57211604116',
#       'authname': 'Dai X.',
#       'surname': 'Dai',
#       'given-name': 'Xinyue',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211611467',
#       'authid': '57211611467',
#       'authname': 'Zhang Y.',
#       'surname': 'Zhang',
#       'given-name': 'Yinghua',
#       'initials': 'Y.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]},
#      {'@_fa': 'true',
#       '@seq': '8',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55752085100',
#       'authid': '55752085100',
#       'authname': 'Chen S.',
#       'surname': 'Chen',
#       'given-name': 'Shizhu',
#       'initials': 'S.',
#       'afid': [{'@_fa': 'true', '$': '60073473'}]},
#      {'@_fa': 'true',
#       '@seq': '9',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57198570929',
#       'authid': '57198570929',
#       'orcid': '0000-0002-5279-0468',
#       'authname': 'Liang X.',
#       'surname': 'Liang',
#       'given-name': 'Xingjie',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60073473'}]},
#      {'@_fa': 'true',
#       '@seq': '10',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55872361100',
#       'authid': '55872361100',
#       'authname': 'Zhang J.',
#       'surname': 'Zhang',
#       'given-name': 'Jinchao',
#       'initials': 'J.',
#       'afid': [{'@_fa': 'true', '$': '60012293'}]}],
#     'authkeywords': 'CaO 2 | chemodynamic therapy | chemotherapy | doxorubicin | ZIF-67',
#     'article-number': '1902137',
#     'source-id': '21100470165',
#     'fund-no': 'B2017201226',
#     'fund-sponsor': 'Natural Science Foundation of Hebei Province',
#     'openaccess': '1',
#     'openaccessFlag': True,
#     'freetoread': {'value': [{'$': 'all'},
#       {'$': 'publisherfullgold'},
#       {'$': 'repository'},
#       {'$': 'repositoryvor'}]},
#     'freetoreadLabel': {'value': [{'$': 'All Open Access'},
#       {'$': 'Gold'},
#       {'$': 'Green'}]}},
#    {'@_fa': 'true',
#     'link': [{'@_fa': 'true',
#       '@ref': 'self',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85074324450'},
#      {'@_fa': 'true',
#       '@ref': 'author-affiliation',
#       '@href': 'https://api.elsevier.com/content/abstract/scopus_id/85074324450?field=author,affiliation'},
#      {'@_fa': 'true',
#       '@ref': 'scopus',
#       '@href': 'https://www.scopus.com/inward/record.uri?partnerID=HzOxMe3b&scp=85074324450&origin=inward'},
#      {'@_fa': 'true',
#       '@ref': 'scopus-citedby',
#       '@href': 'https://www.scopus.com/inward/citedby.uri?partnerID=HzOxMe3b&scp=85074324450&origin=inward'}],
#     'prism:url': 'https://api.elsevier.com/content/abstract/scopus_id/85074324450',
#     'dc:identifier': 'SCOPUS_ID:85074324450',
#     'eid': '2-s2.0-85074324450',
#     'dc:title': 'Axonal iron transport in the brain modulates anxiety-related behaviors',
#     'dc:creator': 'Wang Z.',
#     'prism:publicationName': 'Nature Chemical Biology',
#     'prism:issn': '15524450',
#     'prism:eIssn': '15524469',
#     'prism:volume': '15',
#     'prism:issueIdentifier': '12',
#     'prism:pageRange': '1214-1222',
#     'prism:coverDate': '2019-12-01',
#     'prism:coverDisplayDate': '1 December 2019',
#     'prism:doi': '10.1038/s41589-019-0371-x',
#     'dc:description': 'Iron is essential for a broad range of biochemical processes in the brain, but the mechanisms of iron metabolism in the brain remain elusive. Here we show that iron functionally translocates among brain regions along specific axonal projections. We identified two pathways for iron transport in the brain: a pathway from ventral hippocampus (vHip) to medial prefrontal cortex (mPFC) to substantia nigra; and a pathway from thalamus (Tha) to amygdala (AMG) to mPFC. While vHip–mPFC transport modulates anxiety-related behaviors, impairment of Tha–AMG–mPFC transport did not. Moreover, vHip–mPFC iron transport is necessary for the behavioral effects of diazepam, a well-known anxiolytic drug. By contrast, genetic or pharmacological promotion of vHip–mPFC transport produced anxiolytic-like effects and restored anxiety-like behaviors induced by repeated restraint stress. Taken together, these findings provide key insights into iron metabolism in the brain and identify the mechanisms underlying iron transport in the brain as a potential target for development of novel anxiety treatments.',
#     'citedby-count': '14',
#     'affiliation': [{'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60027631',
#       'afid': '60027631',
#       'affilname': 'Institute of High Energy Physics Chinese Academy of Science',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60002593',
#       'afid': '60002593',
#       'affilname': 'Southern Medical University',
#       'affiliation-city': 'Guangzhou',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/60001604',
#       'afid': '60001604',
#       'affilname': 'Ministry of Education China',
#       'affiliation-city': 'Beijing',
#       'affiliation-country': 'China'},
#      {'@_fa': 'true',
#       'affiliation-url': 'https://api.elsevier.com/content/affiliation/affiliation_id/122260882',
#       'afid': '122260882',
#       'affilname': 'Center for Brain Science and Brain-Inspired Intelligence',
#       'affiliation-city': 'Guangzhou',
#       'affiliation-country': 'China'}],
#     'pubmed-id': '31591566',
#     'prism:aggregationType': 'Journal',
#     'subtype': 'ar',
#     'subtypeDescription': 'Article',
#     'author-count': {'@limit': '100', '@total': '9', '$': '9'},
#     'author': [{'@_fa': 'true',
#       '@seq': '1',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211538346',
#       'authid': '57211538346',
#       'authname': 'Wang Z.',
#       'surname': 'Wang',
#       'given-name': 'Zhuo',
#       'initials': 'Z.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'}]},
#      {'@_fa': 'true',
#       '@seq': '2',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55669263200',
#       'authid': '55669263200',
#       'authname': 'Zeng Y.N.',
#       'surname': 'Zeng',
#       'given-name': 'Yuan Ning',
#       'initials': 'Y.N.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'}]},
#      {'@_fa': 'true',
#       '@seq': '3',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57209944328',
#       'authid': '57209944328',
#       'orcid': '0000-0001-7378-6444',
#       'authname': 'Yang P.',
#       'surname': 'Yang',
#       'given-name': 'Peng',
#       'initials': 'P.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'}]},
#      {'@_fa': 'true',
#       '@seq': '4',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211533102',
#       'authid': '57211533102',
#       'authname': 'Jin L.Q.',
#       'surname': 'Jin',
#       'given-name': 'Li Qiang',
#       'initials': 'L.Q.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'}]},
#      {'@_fa': 'true',
#       '@seq': '5',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55669388500',
#       'authid': '55669388500',
#       'authname': 'Xiong W.C.',
#       'surname': 'Xiong',
#       'given-name': 'Wen Chao',
#       'initials': 'W.C.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'}]},
#      {'@_fa': 'true',
#       '@seq': '6',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57202379453',
#       'authid': '57202379453',
#       'authname': 'Zhu M.Z.',
#       'surname': 'Zhu',
#       'given-name': 'Min Zhen',
#       'initials': 'M.Z.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'}]},
#      {'@_fa': 'true',
#       '@seq': '7',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/56035283300',
#       'authid': '56035283300',
#       'authname': 'Zhang J.Z.',
#       'surname': 'Zhang',
#       'given-name': 'Jun Zhe',
#       'initials': 'J.Z.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '8',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/57211541311',
#       'authid': '57211541311',
#       'authname': 'He X.',
#       'surname': 'He',
#       'given-name': 'Xiao',
#       'initials': 'X.',
#       'afid': [{'@_fa': 'true', '$': '60027631'}]},
#      {'@_fa': 'true',
#       '@seq': '9',
#       'author-url': 'https://api.elsevier.com/content/author/author_id/55650856200',
#       'authid': '55650856200',
#       'orcid': '0000-0002-9059-5321',
#       'authname': 'Zhu X.H.',
#       'surname': 'Zhu',
#       'given-name': 'Xin Hong',
#       'initials': 'X.H.',
#       'afid': [{'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '60001604'},
#        {'@_fa': 'true', '$': '60002593'},
#        {'@_fa': 'true', '$': '122260882'}]}],
#     'source-id': '4000148205',
#     'fund-acr': 'NSFC',
#     'fund-no': '2016A030308005',
#     'fund-sponsor': 'National Natural Science Foundation of China',
#     'openaccess': '0',
#     'openaccessFlag': False}]}}

# %%
#The function "make_scopus_articles_df" takes in the "multiple_author_article_list" and uses json_normalize to
#flatten the json contained in the "entry" field. The function returns a dataframe called the "scopus_articles_df".

def make_scopus_articles_df(multiple_author_article_list):
    #final_list = json_normalize(multiple_author_list, meta=["search-results"], record_path=["search-results", "entry"])
    scopus_articles_df = pd.DataFrame.from_dict(pd.json_normalize(multiple_author_article_list, meta=["search-results"], record_path=["search-results", "entry"]),orient="columns")
    
    return scopus_articles_df

scopus_articles_df = make_scopus_articles_df(article_response_2.json())

title_description_df = scopus_articles_df[["dc:title", "dc:description"]]
title_description_df
# Out:
#                                              dc:title  \
# 0   Microfluidic Synthesis of Functional Nanoparti...
# 1   Simultaneous delivery of DNA vaccine and hydro...
# 2   Size-dependent tissue-specific biological effe...
# 3   Nucleic acid nanoparticles at a crossroads of ...
# 4   Selenium modulated gut flora and promoted deco...
# 5   Plasmon-Enhanced Oxidase-Like Activity and Cel...
# 6   Cold-Responsive Nanoparticle Enables Intracell...
# 7   Turning Challenges into Opportunities for Prom...
# 8   Organoplatinum-Substituted Polyoxometalate Inh...
# 9   Predominance of secondary organic aerosol to p...
# 10  Plastin 3 down-regulation augments the sensiti...
# 11    Pain management using nanotechnology approaches
# 12  The role of nuclear chemistry and radiochemist...
# 13  Toxicity Evaluation of One-Dimensional Nanopar...
# 14  Synthesis of Low-Viscosity Ionic Liquids for A...
# 15  Chemical Analysis and Imaging of Fingerprints ...
# 16  Design and bio-applications of biological meta...
# 17  Chinese Public and Nanoresearchers’ Perception...
# 18  Applicability and limitations in the character...
# 19  Carbon Nanomaterials Stimulate HMGB1 Release F...
# 20  Evaluation of microbial shifts caused by a sil...
# 21     Recent Advances in Hemostasis at the Nanoscale
# 22  Emerging Delivery Strategies of Carbon Monoxid...
# 23  Self-Supply of O<inf>2</inf> and H<inf>2</inf>...
# 24  Axonal iron transport in the brain modulates a...
#
#                                        dc:description
# 0   This chapter focuses on microfluidic-based syn...
# 1   The activation and maturation of dendritic cel...
# 2   Background: Understanding the in vivo size-dep...
# 3   Vaccines and immunotherapies involve a variety...
# 4   Introduction: Selenium plays important roles i...
# 5   Local surface plasmon resonance (LSPR)-enhance...
# 6   Conventional cryopreservation of mammalian cel...
# 7   Systems thinking encompasses a set of skills f...
# 8   Aggregated β-amyloid (Aβ) is widely considered...
# 9   Reactive oxygen species (ROS) are believed to ...
# 10  Plastin 3 (PLS3) overexpression may serve as a...
# 11  The proper treatment of pain is yet a major me...
# 12  Nowadays there is an increasing demand of engi...
# 13  In this study, the toxicity of two one-dimensi...
# 14  Two types of ionic liquids (ILs), 1-(3-hexenyl...
# 15  Fingerprint analysis is of great significance ...
# 16  Biological metal-organic frameworks (bioMOFs) ...
# 17  Public and experts’ perceptions of benefits an...
# 18  The dispersion protocol used to administer nan...
# 19  Carbon nanomaterials (CNMs) are widely used in...
# 20  Background: Before chemicals, pesticides and b...
# 21  Rapid and effective hemostatic materials have ...
# 22  Carbon monoxide (CO) therapy has emerged as a ...
# 23  Combined chemo/chemodynamic therapy is a promi...
# 24  Iron is essential for a broad range of biochem...
