# %% [markdown]
# ## Use multiple Scopus Author IDs to retrieve lists of articles by author

# %%
pip install numpy --upgrade --user

# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import re
import io
from config import api_key
from collections import OrderedDict
from pandas.io.json import json_normalize  
from nltk.corpus import stopwords, reuters
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
import re
import matplotlib.pyplot as plt
import time

# Code to download corpora
import nltk
lemmatizer = WordNetLemmatizer()
# Out:
# Bad key savefig.frameon in file C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 421 ('savefig.frameon : True')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.4/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.level in file C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 472 ('verbose.level  : silent      # one of silent, helpful, debug, debug-annoying')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.4/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key verbose.fileo in file C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle, line 473 ('verbose.fileo  : sys.stdout  # a log filename, sys.stdout or sys.stderr')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.3.4/matplotlibrc.template
# or from the matplotlib source distribution
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\gss8640\Anaconda3\envs\pyvizenv\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# Declare necessary parameters for Scopus request API search tool
url = "http://api.elsevier.com/content/search/scopus?" + "?format=json"
headers = {"X-ELS-APIKey": api_key, 'Accept':'application/json'}
view = "Complete"

# %%
# Declare the timeframe to search by start and end years
# Year is the lowest granularity for this search function
start_year = 2005
end_year = 2010
if start_year == end_year:
    date = str(start_year)
else: 
    date = str(start_year) + "-" + str(end_year)

# Generate a lists of dates for the requested timeframe
date_list = []
for date in range(start_year, end_year + 1):
    date_list.append(int(date))
    
# date_list

# %%
# Input the query search term
query = "nanosafety"

# %%
# Test search function to determine the total results from the Get Request for the Specified Date Range
def total_results_funt(date_list):
    total_results = []
    for i in date_list:
        parameters = {"query": query, "view": view, "date": str(i), "count": 25, "start": 0}
        article_response = requests.get(url, headers=headers, params=parameters)
        article_response_json = article_response.json()
        total_results.append(int(article_response_json['search-results']['opensearch:totalResults']))
    return total_results

total_results = total_results_funt(date_list)
total_results
# Out:
# [6, 4, 17, 39, 49, 82]

# %%
# Create an annual frequency bar plot for query search
frequency_df = pd.DataFrame([date_list, total_results]).T
frequency_df.columns = ['Year', 'Frequency']
plt.figure(figsize =(14, 10))
plt.bar(frequency_df['Year'], frequency_df['Frequency'])
plt.xlabel('Year')
plt.xticks(frequency_df['Year'], date_list)
plt.ylabel('Frequency')
plt.rc('font', size=20) #controls default text size
plt.title('Annual Frequency of Nanosafety')
plt.savefig('Title_Query_Frequency.jpeg')

# %%
list = []
list.append(date_list)
list.append(total_results)
list

# %%
x = start_year -1
while x <= end_year:
    x = x + 1
    parameters = {"query": query, "view": view, "date": str(x), "count": 1, "start": 0}
    article_response = requests.get(url, headers=headers, params=parameters)
    article_response_json = article_response.json()
    y = int(article_response_json['search-results']['opensearch:totalResults'])
    for n in range(0, y, 1):
        parameters = {"query": query, "view": view, "date": x, "count": 25, "start": n}
        article_response = requests.get(url, headers=headers, params=parameters)
        article_response_json = article_response.json()
        scopus_articles_df = pd.DataFrame.from_dict(json_normalize(article_response_json, meta=["search-results"], record_path=["search-results", "entry"]), orient="columns")
        date_title_description_df = scopus_articles_df[["prism:coverDate", "dc:title", "dc:description"]]
        date_title_description_df.columns = ['Date','Title','Content']
        pd.to_datetime(date_title_description_df['Date'], format = "%Y-%m-%d")
        date_title_description_df.sort_values(by='Date')
        date_title_description_df = date_title_description_df.set_index('Date')
        scopus_search_appended_df = scopus_search_appended_df.append(date_title_description_df)

# %%
scopus_search_appended_df = pd.DataFrame()
for x in range (start_year, end_year + 1):
    parameters = {"query": query, "view": view, "date": str(x), "start": 0}
    article_response = requests.get(url, headers=headers, params=parameters)
    article_response_json = article_response.json()
    y = int(article_response_json['search-results']['opensearch:totalResults'])
    for n in range(0, y, 25):
        parameters = {"query": query, "view": view, "date": x, "count": 25, "start": n}
        article_response = requests.get(url, headers=headers, params=parameters)
        article_response_json = article_response.json()
        scopus_articles_df = pd.DataFrame.from_dict(json_normalize(article_response_json, meta=["search-results"], record_path=["search-results", "entry"]), orient="columns")
        date_title_description_df = scopus_articles_df[["prism:coverDate", "dc:title", "dc:description"]]
        date_title_description_df.columns = ['Date','Title','Content']
        pd.to_datetime(date_title_description_df['Date'], format = "%Y-%m-%d")
        date_title_description_df.sort_values(by='Date')
        date_title_description_df = date_title_description_df.set_index('Date')
        scopus_search_appended_df = scopus_search_appended_df.append(date_title_description_df)
        pass

# %%
scopus_search_appended_df
# Out:
#                                                         Title  \
# Date
# 2005-12-12  Military nanotechnology: Potential application...
# 2005-12-01  Translocation of inhaled TiO<inf>2</inf> nanop...
# 2005-10-01  Status of study on biological and toxicologica...
# 2005-04-01  The promise and threat of nanotechnology: Can ...
# 2005-03-01  Environmentally responsible development of nan...
# 2005-02-01  Societal implications of nanoscience and nanot...
# 2006-12-01  The tension between fiction and precaution in ...
# 2006-09-01  The nano enterprise: A survey of health and sa...
# 2006-01-01  The promise and threat of nanotechnology: Can ...
# 2006-01-01  Progress in governance of converging technolog...
# 2007-12-10  Ultrahigh reactivity provokes nanotoxicity: Ex...
# 2007-12-01  A sustainable development for nanotechnologies...
# 2007-12-01  INDA events: Filtration, vision and the IDEA07...
# 2007-10-18  Switchable semiconductive property of the poly...
# 2007-10-03  Regulatory instruments for nanotechnology: Wor...
# 2007-09-01  Transport of intranasally instilled fine Fe<in...
# 2007-08-18                                         Nanosafety
# 2007-08-15  Formulating the problems for environmental ris...
# 2007-08-01  Social and ethical interactions with nano: Map...
# 2007-06-14  Photochemical and photophysical properties of ...
# 2007-03-01  The way of stabilizing non-IPR fullerenes and ...
# 2007-01-30  Acute toxicity and biodistribution of differen...
# 2007-01-30  Investigation of mercury-containing proteins b...
# 2007-01-01  Influence of intranasal instilled titanium dio...
# 2007-01-01  Determination of Mercury in Fish by Isotope Di...
# 2007-01-01  Toxicological and biological effects of nanoma...
# 2007-01-01  What do we know about innovation in nanotechno...
# 2008-12-15  Potential neurological lesion after nasal inst...
# 2008-12-05  Time-dependent translocation and potential imp...
# 2008-12-01  Preparation and photocatalytic performance of ...
# ...                                                       ...
# 2010-06-01  Toxicity of zinc oxide nanoparticles to zebraf...
# 2010-05-25  Potent angiogenesis inhibition by the particul...
# 2010-05-19  The big red shift of photoluminescence of Mn d...
# 2010-05-15                          Microfluidic western blot
# 2010-05-06  First endohedral metallofullerene-containing p...
# 2010-05-01  Effects of ZnO nanoparticles on antioxidant en...
# 2010-05-01  Structures and electronic properties of M@Au<i...
# 2010-04-20  Metallofullerene nanoparticles circumvent tumo...
# 2010-04-12  Enhanced exciton migration in electrospun poly...
# 2010-04-01  Loop-mediated isothermal amplification integra...
# 2010-03-24  Chemistry of carbon nanotubes in biomedical ap...
# 2010-03-12  Applications and toxicological issues surround...
# 2010-03-08  Physico-chemical behaviour and algal toxicity ...
# 2010-03-05  Size-dependent mechanical properties of PVA na...
# 2010-03-01  Preparation of anatase-type TiO<inf>2</inf> na...
# 2010-03-01  Therapeutic strategies underpinning the develo...
# 2010-02-23  [Gd@C<inf>82</inf>(OH)<inf>22</inf>]<inf>n</in...
# 2010-02-01  Polycationic nanoparticles as nonviral vectors...
# 2010-01-26  Use of a rapid cytotoxicity screening approach...
# 2010-01-19  Fabrication of necklace-like structures via el...
# 2010-01-15  Probing the magnetic and structural properties...
# 2010-01-01  Functionalization of Cloisite 30B with fluores...
# 2010-01-01  Electrochemical tuning of spin states of the e...
# 2010-01-01  Red, green, and blue luminescence from ZnGa<in...
# 2010-01-01  Characterization of gold nanorods in vivo by i...
# 2010-01-01  Reported nanosafety practices in research labo...
# 2010-01-01  Experimental evaluation of individual protecti...
# 2010-01-01  Circumventing tumor resistance to chemotherapy...
# 2010-01-01  Personal protective equipment against nanopart...
# 2010-01-01  Effects of rare earth oxide nanoparticles on r...
#
#                                                       Content
# Date
# 2005-12-12  With revolutionary changes in nanotechnology (...
# 2005-12-01  Nanosized TiO2 is widely used for cleaning air...
# 2005-10-01  Because the physical and chemical properties o...
# 2005-04-01  The growing presence of the products of nanote...
# 2005-03-01                                                NaN
# 2005-02-01  The balance between the potential benefits and...
# 2006-12-01                                                NaN
# 2006-09-01  Nanotechnology is evolving to become a leading...
# 2006-01-01  The growing presence of the products of nanote...
# 2006-01-01  It is expected that convergence of nanotechnol...
# 2007-12-10  Recently, studies on the biological effects of...
# 2007-12-01                                                NaN
# 2007-12-01  The 2006 edition of the annual INDA Filtration...
# 2007-10-18  The temperature-sensitive property of polyhydr...
# 2007-10-03                                                NaN
# 2007-09-01  It has been demonstrated that inhaled fine (d<...
# 2007-08-18                                                NaN
# 2007-08-15                                                NaN
# 2007-08-01  There is a rapidly expanding field of research...
# 2007-06-14  The photochemical and photophysical properties...
# 2007-03-01  Recently, a new non-IPR chlorofullerene C54C18...
# 2007-01-30  In order to evaluate the toxicity of TiO2 part...
# 2007-01-30  In order to investigate trace mercury-containi...
# 2007-01-01  OBJECTIVE: To investigate the influence of int...
# 2007-01-01  A method for mild extraction and subsequent de...
# 2007-01-01  In this paper, we summarise the most recent fi...
# 2007-01-01  This contribution formulates a number of propo...
# 2008-12-15  Nanoscale titanium dioxide (TiO2) is massively...
# 2008-12-05  Nanoparticles can be administered via nasal, o...
# 2008-12-01  Titania nanotubes (TNTs) were synthesized by h...
# ...                                                       ...
# 2010-06-01  The biological impact of engineered nanomateri...
# 2010-05-25  Antiangiogenesis is an effective strategy for ...
# 2010-05-19  The red photoluminescence of Mn dopants in MnS...
# 2010-05-15  We develop a novel method for Western blot bas...
# 2010-05-06  Metallofullerene-containing copolymers (0.12, ...
# 2010-05-01  The toxicity effects of nano-ZnO suspension on...
# 2010-05-01  The geometries and electronic properties of th...
# 2010-04-20  Cisplatin is a chemotherapeutic drug commonly ...
# 2010-04-12  We present the studies on static and transient...
# 2010-04-01  This work shows that loop-mediated isothermal ...
# 2010-03-24  Carbon nanotubes (CNTs) have attracted great i...
# 2010-03-12  With the rapid development of nanotechnology, ...
# 2010-03-08  In assessing the risks posed by nanomaterials ...
# 2010-03-05  Organic nanowires/fibers have great potential ...
# 2010-03-01  Anatase-type TiO2 fine powders were synthesize...
# 2010-03-01  The HIV replication cycle offers multiple targ...
# 2010-02-23  Dendritic cells play a pivotal role in host im...
# 2010-02-01  Currently, polycationic nanoparticles (polycat...
# 2010-01-26  The establishment of verifiably safe nanotechn...
# 2010-01-19  We report a one-step method to fabricate neckl...
# 2010-01-15  The geometries, electronic, and magnetic prope...
# 2010-01-01  An organo-montmorillonite (Cloisite® 30B) was ...
# 2010-01-01                                                NaN
# 2010-01-01  Large-area (>1 cm2), vertically aligned ZnGa2O...
# 2010-01-01  Integrated analytical techniques were used to ...
# 2010-01-01                                                NaN
# 2010-01-01  In this study different conventional individua...
# 2010-01-01  Patient relapse and metastasis of malignant ce...
# 2010-01-01  Nanomaterials manufacture and use are in full ...
# 2010-01-01  The phytotoxicity of four rare earth oxide nan...
#
# [197 rows x 2 columns]

# %%
scopus_search_appended_df = pd.DataFrame()
n = 0
for i in range(0, len(list[0])):
    for r in r list[0]:
        while n <= r:
            n = n+ 25
        parameters = {"query": query, "view": view, "date": str(list[0][i]), "count": 25, "start": n}
        article_response = requests.get(url, headers=headers, params=parameters)
        article_response_json = article_response.json()
        scopus_articles_df = pd.DataFrame.from_dict(json_normalize(article_response_json, meta=["search-results"], record_path=["search-results", "entry"]), orient="columns")
        date_title_description_df = scopus_articles_df[["prism:coverDate", "dc:title", "dc:description"]]
        date_title_description_df.columns = ['Date','Title','Content']
        pd.to_datetime(date_title_description_df['Date'], format = "%Y-%m-%d")
        date_title_description_df.sort_values(by='Date')
        date_title_description_df = date_title_description_df.set_index('Date')
        scopus_search_appended_df = scopus_search_appended_df.append(date_title_description_df)

scopus_search_appended_df

# %%
# Search request function 
# Scopus request has a maximum of 5000 articles returned per year
def search_request_funt(total_results, query, date_list):
    scopus_search_appended_df = pd.DataFrame()
    dates_df=pd.DataFrame(date_list,columns=["Dates"])
    results_df=pd.DataFrame(total_results,columns=["Results"])
    final_df=dates_df.join(results_df)

    for n in ran:
            parameters = {"query": query, "view": view, "date": str(final_df.iloc[i]['Dates']), "count": 25, "start": int(final_df.iloc[i]['Results'])}
            article_response = requests.get(url, headers=headers, params=parameters)
            article_response_json = article_response.json()
            scopus_articles_df = pd.DataFrame.from_dict(json_normalize(article_response_json, meta=["search-results"], record_path=["search-results", "entry"]), orient="columns")
            date_title_description_df = scopus_articles_df[["prism:coverDate", "dc:title", "dc:description"]]
            date_title_description_df.columns = ['Date','Title','Content']
            pd.to_datetime(date_title_description_df['Date'], format = "%Y-%m-%d")
            date_title_description_df.sort_values(by='Date')
            date_title_description_df = date_title_description_df.set_index('Date')
            scopus_search_appended_df = scopus_search_appended_df.append(date_title_description_df)

    return scopus_search_appended_df

# Create and check scopus search dataframe
scopus_search_appended_df = search_request_funt(total_results, query, date_list)
scopus_search_appended_df

# %%
# Convert dataframe title column to string text
def dataframe_to_string(scopus_search_appended_df):
    for row in scopus_search_appended_df['Title']:
        big_title_string = ' '.join(scopus_search_appended_df['Title'])
    return big_title_string
big_title_string = dataframe_to_string(scopus_search_appended_df)
# big_title_string

# %%
# Natural language toolkit function to process string of text
def process_text(doc):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    sw_addons = {'using', 'via'}
    re_clean = regex.sub('', doc)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    return ' '.join(output)
input_text_title = process_text(big_title_string)

# %%
# Generate WordCloud for titles pulled for the seleted query within the timeframe
wc_title = WordCloud(width=1200, height=800, max_words=25, background_color="white").generate(input_text_title)
plt.figure()
plt.imshow(wc_title, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Output image of WordCloud
image_title = wc_title.to_image()
image_title.save("Title_WordCloud.jpg")

# %%
for row in nanosafety_appended_df:
    big_string_content = str(nanosafety_appended_df['Content'].to_list())
    
big_string_content

# %%
input_text_content = process_text(big_string_content)

# %%
wc_content = WordCloud(width=1200, height=800, background_color="white", max_words=30).generate(input_text_content)
plt.figure()
plt.imshow(wc_content, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
image_content = wc_content.to_image()
image_content.show()

# %%
data = pd.DataFrame(nanosafety_appended_df.groupby("Date").size())
data = data.reset_index()
data.columns = ['Date', 'Count']
data['Date'] = pd.to_datetime(data['Date'], infer_datetime_format = True).apply(lambda x: x.strftime('%Y-%m'))
data_month = pd.DataFrame(data.groupby("Date").size())
data_month = data_month.reset_index()
data_month.columns = ['Date', 'Count']
#data_month.plot(x ='Date', y='Count', kind = 'bar')
# data_month
